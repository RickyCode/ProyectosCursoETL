# %%
''' Intento de extraer los nombres de los países para poder establecer los 
países con mayor frecuencia de sismos: '''


# def extract_country(place):
#   if ',' in place:
#     return place[::-1][:place[::-1].find(',')][::-1].replace(' ','')
#   return place[::-1][:place[::-1].find(' ')+1][::-1].replace(' ','')

# territories = [extract_country(x) for x in df_earthquake.place.values]
# set(territories)

123456789 123456789 123456789 123456789 123456789 123456789 123456789 123456789 


# earthquake2.year.iloc[::-1].hist(bins=30, figsize=(15,6))

# plt.xticks(rotation='vertical')

# plt.show()
